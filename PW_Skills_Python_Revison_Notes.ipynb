# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekgutte200/Python_programs/blob/main/PW_Skills_Python_Revison_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Topics to be Covered**
# 🙂
# 1. Introduction To Python
# 2. Predified Keywords
# 3. Mutability and Immutability
# 4. Operators
# 5. Type Casting
# 6. Conditionals
# 7. Loops
#
# --------------------------------------
#
# 8. Strings
# 9. Lists
# 10. Tuple and Sets
# 11. Dictionary
#
# ---------------------------------------
#
# 12. Functions
# 13. Iterators and Generators
# 14. Lambda, Map and Reduce

# %% [markdown]
# # **1. Introduction To Python**

# %% [markdown]
# **Why Do We Need Programming ?**
#
# 1. To communicate with digital machines and make them work accordingly
#
#
# 2. Today in the programming world , we have more than 800 languages available.
#
#
# 3. And every language is designed to fulfill a particular kind of requirement

# %% [markdown]
# **Programming** is like giving instructions to a computer to solve problems or complete tasks. We need programming because:
#
# 1. Automation: It helps automate repetitive tasks, saving time and effort. For example, a program can calculate hundreds of numbers in seconds, which would take a person much longer.
#
# 2. Problem-solving: Programming allows us to create solutions for real-world problems, like building websites, apps, or even managing data for businesses.
#
# 3. Efficiency: Computers can process large amounts of information quickly, and programming enables us to use that power to make things faster, more accurate, and more organized.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Important Features Of Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Predefined Keywords**

# %% [markdown]
# **What is Variable**
# 🙂

# %% [markdown]
# **Definition 1** : Variable: A named value, that potentially can be changed as the program runs

# %% [markdown]
# **Definition 2**: a named location in a computer's memory that stores data that can change

# %% [markdown]
# **Definition 3**: A variable is a named container that stores data, which can be known or unknown, and is used throughout a program

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  specific means that each variable has a unique and clearly defined name that is used to store and access a particular value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# An **identifier** is simply the name used to identify a variable, function, class, module, or other objects in Python. It follows certain rules:
#
# 1. It must start with a letter (A-Z or a-z) or an underscore (_).
# 2. The rest of the name can include letters, digits (0-9), or underscores.
# 3. Identifiers are case-sensitive, meaning myVar and myvar would be two different identifiers.
# 4. Reserved keywords (like if, for, class, etc.) cannot be used as identifiers.
#
# **Examples of valid identifiers:**
#
# 1. my_variable
# 2. userName
# 3. _count
#
# **Examples of invalid identifiers:**
#
# 1. 2variable (cannot start with a number)
# 2. if (reserved keyword)

# %% [markdown]
# In Python, predefined keywords (also known as reserved words) are special words that have a specific meaning to the Python interpreter. These keywords are part of the Python syntax and cannot be used as variable names, function names, or identifiers because they are reserved for specific purposes in the language.
#
# Some examples of Python's predefined keywords include:
#
# 1. if, else, elif: For conditional statements.
# 2. for, while: For loops.
# 3. def: To define a function.
# 4. class: To define a class.
# 5. return: To return a value from a function.
# 6. try, except: For handling exceptions.
# 7. import: To import a module.
# 8. True, False: Boolean values.
# 9. None: Represents the absence of a value.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # **3. Mutability and Immutability**

# %% [markdown]
# 1. **Mutable:** Can be changed in place (e.g., Lists, Dictionaries).
# 2. **Immutable:** Cannot be changed in place (e.g., Strings, Tuples).

# %%
my_list=[1,2,3,4]

# %%
my_list[3]=500

# %%
my_list
# Out:
# [100, 2, 3, 500]

# %%
x='Hi'

# %%
x[0]='w'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d98e00d86dce> in <cell line: 1>()
# ----> 1 x[0]='w'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # **4. Operators**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=10
b=20

res=10+20

# %%
2/3
# Out:
# 0.6666666666666666

# %%
2//3
# Out:
# 0

# %%
2 ** 2
# Out:
# 4

# %% [markdown]
# The floor division operator (//) in Python divides two numbers and returns the largest integer less than or equal to the result. In simple terms, it "rounds down" the result to the nearest whole number.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
5 and 6
# Out:
# 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
~3
# Out:
# -4

# %% [markdown]
# # **5. Type Casting**

# %% [markdown]
# In Python, we can convert one type of variable to another type. This conversion is called type casting or type conversion.

# %% [markdown]
# Python performs the following two types of casting.
#
# 1. Implicit casting: The Python interpreter automatically performs an implicit Type conversion, which avoids loss of data.
# 2. Explicit casting: The explicit type conversion is performed by the user using built-in functions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **6. Conditionals**

# %% [markdown]
# # **7. Loops**

# %% [markdown]
# # **8. Strings**

# %% [markdown]
# # **9. Lists**

# %% [markdown]
# # **10 Tuple and Sets**

# %% [markdown]
# # **11. Dictionary**

# %% [markdown]
# # **12. Functions**

# %% [markdown]
# In Python, the function is a block of code defined with a name. We use functions whenever we need to perform the same task multiple times without writing the same code again. It can take arguments and returns the value.

# %% [markdown]
# **Types of Functions**
# Python support two types of functions
#
# 1. Built-in function
# 2. User-defined function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Positional Arguments

# %% [markdown]
# Keyword Arguments

# %% [markdown]
# Variable-length Arguments

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recursive Function

# %% [markdown]
# Python Anonymous/Lambda Function

# %% [markdown]
# Sometimes we need to declare a function without any name. The nameless property function is called an anonymous function or lambda function.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
add = lambda x, y: x + y
print(add(5, 3))  # Output: 8
# Out:
# 8

# %%
greet = lambda: "Hello, World!"
print(greet())  # Output: "Hello, World!"
# Out:
# Hello, World!

# %%
# Program for even numbers without lambda function
def even_numbers(nums):
    even_list = []
    for n in nums:
        if n % 2 == 0:
            even_list.append(n)
    return even_list

num_list = [10, 5, 12, 78, 6, 1, 7, 9]
ans = even_numbers(num_list)
print("Even numbers are:", ans)
# Out:
# Even numbers are: [10, 12, 78, 6]

# %%
# Program for even number with a lambda function
l = [10, 5, 12, 78, 6, 1, 7, 9]
even_nos = list(filter(lambda x: x % 2 == 0, l))
print("Even numbers are: ", even_nos)
# Out:
# Even numbers are:  [10, 12, 78, 6]

# %% [markdown]
# **Map**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In Python, the map() function is used to apply some functionality for every element present in the given sequence and generate a new series with a required modification.

# %%
list1 = [2, 3, 4, 8, 9]
list2 = list(map(lambda x: x*x*x, list1))
print("Cube values are:", list2)
# Out:
# Cube values are: [8, 27, 64, 512, 729]

# %% [markdown]
# **Reduce**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. In Python, the reduce() function is used to minimize sequence elements into a single value by applying the specified condition.
#
# 2. The reduce() function is present in the functools module; hence, we need to import it using the import statement before using it.

# %%
from functools import reduce
list1 = [20, 13, 4, 8, 9]
add = reduce(lambda x, y: x*y, list1)
print("Addition of all list elements is : ", add)
# Out:
# Addition of all list elements is :  74880

# %% [markdown]
# # **13. Iterators and Generators**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Iterable is an object, that one can iterate over. It generates an Iterator when passed to iter() method.
# 2.  An iterator is an object, which is used to iterate over an iterable object using the __next__() method. Iterators have the __next__() method, which returns the next item of the object.

# %%
l1=[1,2,3,4]

# %%
for i in l1:
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
print(dir(l1))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
# next(l1)

# %%
k=iter(l1)

# %%
print(dir(k))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__length_hint__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__']

# %%
next(k)
# Out:
# 1

# %% [markdown]
# **Generators**

# %% [markdown]
# A Generator in Python is a function that returns an iterator using the Yield keyword.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def simpleGeneratorFun():
    yield 1
    yield 2
    yield 3

# Driver code to check above generator function
for value in simpleGeneratorFun():
    print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# yield: This is the key difference between generators and regular functions. The yield statement pauses the function saving all its states and later continues from there on successive calls.

# %%
def square_numbers(numbers):
    for num in numbers:
        yield num * num

# Using the generator
nums = [1, 2, 3, 4, 5]
squares = square_numbers(nums)
'''
for square in squares:
    print(square)
    '''
# Out:
# '\nfor square in squares:\n    print(square)\n    '

# %%
squares
# Out:
# <generator object square_numbers at 0x7eddb7d3b3e0>

# %%
next(squares)
# Out:
# 4

# %% [markdown]
# # **14. Lambda, Map and Reduce**

# %% [markdown]
# **filter**

# %%
l = [-10, 5, 12, -78, 6, -1, -7, 9]
positive_nos = list(filter(lambda x: x > 0, l))
print("Positive numbers are: ", positive_nos)
# Out:
# Positive numbers are:  [5, 12, 6, 9]
